# %% [markdown]
# # OCTA MAE — Encoder Evaluation
#
# Evaluacia 5 experimentov pomocou linear probe na zmrazených embeddingoch.

# %% [markdown]
# # Imports + Cesty

# %%
import sys
from pathlib import Path

sys.path.insert(0, "scripts")
from octa_mae_eval import run_encoder_eval_final

ENCODER_ROOT = Path().resolve()
RESULTS      = ENCODER_ROOT / "results"

EXCEL_PATH = ENCODER_ROOT / "data" / "master_excels" / "master_table.xlsx"
DATA_ROOT  = ENCODER_ROOT / "data"

P1_BASELINE = RESULTS / "phase1" / "baseline" / "pretrained" / "final_encoder.pth"
P1_BALANCED = RESULTS / "phase1" / "balanced" / "pretrained" / "final_encoder.pth"
P2_BASELINE = RESULTS / "phase2" / "baseline" / "pretrained" / "final_encoder.pth"
P2_BALANCED = RESULTS / "phase2" / "balanced" / "pretrained" / "final_encoder.pth"
P2_GRL      = RESULTS / "phase2" / "grl"      / "pretrained" / "final_encoder.pth"

paths = {
    "P1 Baseline": P1_BASELINE,
    "P1 Balanced": P1_BALANCED,
    "P2 Baseline": P2_BASELINE,
    "P2 Balanced": P2_BALANCED,
    "P2 GRL"     : P2_GRL,
}

print(f"Encoder root: {ENCODER_ROOT}\n")
for name, path in paths.items():
    status = "OK" if path.exists() else "NENAJDENY"
    print(f"  {name:<15} {status:<12} {path}")
# Out:
# Encoder root: C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders
#
#   P1 Baseline     OK           C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\baseline\pretrained\final_encoder.pth
#   P1 Balanced     OK           C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\balanced\pretrained\final_encoder.pth
#   P2 Baseline     OK           C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\baseline\pretrained\final_encoder.pth
#   P2 Balanced     OK           C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\balanced\pretrained\final_encoder.pth
#   P2 GRL          OK           C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\grl\pretrained\final_encoder.pth

# %% [markdown]
# ---
# ## Phase 1 Baseline

# %%
out_exp1 = run_encoder_eval_final(
    encoder_path = P1_BASELINE,
    excel_path   = EXCEL_PATH,
    data_root    = DATA_ROOT,
)
# Out:
# ========== ENCODER EVAL ==========
# Encoder   : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\baseline\pretrained\final_encoder.pth
# Eval dir  : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\baseline\pretrained\eval
# Eval name : phase1_baseline
#
# Vysledky najdene: C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\baseline\pretrained\eval\phase1_baseline_results.json
#
# ===== SUMMARY (z cache) =====
# SVP only - Dataset: 0.8793
# SVP only - Disease: 0.7000
# DCP only - Dataset: 0.9511
# DCP only - Disease: 0.5714
# Concat - Dataset: 0.9196
# Concat - Disease: 0.6992
# Single - SVP vs DCP: 1.0000

# %% [markdown]
# ---
# ## Phase 1 Balanced

# %%
out_exp2 = run_encoder_eval_final(
    encoder_path = P1_BALANCED,
    excel_path   = EXCEL_PATH,
    data_root    = DATA_ROOT,
)
# Out:
# ========== ENCODER EVAL ==========
# Encoder   : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\balanced\pretrained\final_encoder.pth
# Eval dir  : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\balanced\pretrained\eval
# Eval name : phase1_balanced
#
# Vysledky najdene: C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase1\balanced\pretrained\eval\phase1_balanced_results.json
#
# ===== SUMMARY (z cache) =====
# SVP only - Dataset: 0.9010
# SVP only - Disease: 0.7051
# DCP only - Dataset: 0.9435
# DCP only - Disease: 0.5974
# Concat - Dataset: 0.9434
# Concat - Disease: 0.7632
# Single - SVP vs DCP: 1.0000

# %% [markdown]
# ---
# ## Phase 1 Baseline -> Phase 2 Baseline

# %%
out_exp3 = run_encoder_eval_final(
    encoder_path = P2_BASELINE,
    excel_path   = EXCEL_PATH,
    data_root    = DATA_ROOT,
)
# Out:
# ========== ENCODER EVAL ==========
# Encoder   : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\baseline\pretrained\final_encoder.pth
# Eval dir  : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\baseline\pretrained\eval
# Eval name : phase2_baseline
#
# Vysledky najdene: C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\baseline\pretrained\eval\phase2_baseline_results.json
#
# ===== SUMMARY (z cache) =====
# SVP only - Dataset: 0.8588
# SVP only - Disease: 0.7735
# DCP only - Dataset: 0.9682
# DCP only - Disease: 0.5995
# Concat - Dataset: 0.9006
# Concat - Disease: 0.7282
# Single - SVP vs DCP: 1.0000

# %% [markdown]
# ---
# ## Phase 1 Balanced -> Phase 2 Balanced

# %%
out_exp4 = run_encoder_eval_final(
    encoder_path = P2_BALANCED,
    excel_path   = EXCEL_PATH,
    data_root    = DATA_ROOT,
)
# Out:
# ========== ENCODER EVAL ==========
# Encoder   : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\balanced\pretrained\final_encoder.pth
# Eval dir  : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\balanced\pretrained\eval
# Eval name : phase2_balanced
#
# Vysledky najdene: C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\balanced\pretrained\eval\phase2_balanced_results.json
#
# ===== SUMMARY (z cache) =====
# SVP only - Dataset: 0.8588
# SVP only - Disease: 0.7735
# DCP only - Dataset: 0.9682
# DCP only - Disease: 0.5995
# Concat - Dataset: 0.9006
# Concat - Disease: 0.7282
# Single - SVP vs DCP: 1.0000

# %% [markdown]
# ---
# ## Phase 1 Balanced -> Phase 2 + GRL

# %%
out_exp5 = run_encoder_eval_final(
    encoder_path = P2_GRL,
    excel_path   = EXCEL_PATH,
    data_root    = DATA_ROOT,
)
# Out:
# ========== ENCODER EVAL ==========
# Encoder   : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\grl\pretrained\final_encoder.pth
# Eval dir  : C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\grl\pretrained\eval
# Eval name : phase2_grl
#
# Vysledky najdene: C:\Users\klara\Desktop\Fianl\03_Model_Training\encoders\results\phase2\grl\pretrained\eval\phase2_grl_results.json
#
# ===== SUMMARY (z cache) =====
# SVP only - Dataset: 0.8786
# SVP only - Disease: 0.6691
# DCP only - Dataset: 0.9264
# DCP only - Disease: 0.5609
# Concat - Dataset: 0.9300
# Concat - Disease: 0.8376
# Single - SVP vs DCP: 1.0000

# %% [markdown]
# ---
# ## Bunka 7 — Porovnanie vsetkych experimentov

# %%
experiments = {
    "Exp1 P1 Baseline"         : out_exp1,
    "Exp2 P1 Balanced"         : out_exp2,
    "Exp3 P1Base -> P2Base"    : out_exp3,
    "Exp4 P1Bal  -> P2Bal"     : out_exp4,
    "Exp5 P1Bal  -> P2GRL"     : out_exp5,
}

metrics = [
    "SVP only - Disease",
    "SVP only - Dataset",
    "DCP only - Disease",
    "DCP only - Dataset",
    "Concat - Disease",
    "Concat - Dataset",
    "Single - SVP vs DCP",
]

col_w = 28
header = f"{'Metrika':<{col_w}}" + "".join(f"{name:>22}" for name in experiments)
print(header)
print("-" * len(header))

for metric in metrics:
    row = f"{metric:<{col_w}}"
    for exp_out in experiments.values():
        val = exp_out["results"].get(metric, {}).get("bal_acc", None)
        row += f"{val:>22.4f}" if val is not None else f"{'N/A':>22}"
    print(row)
# Out:
# Metrika                           Exp1 P1 Baseline      Exp2 P1 Balanced Exp3 P1Base -> P2Base  Exp4 P1Bal  -> P2Bal  Exp5 P1Bal  -> P2GRL
# ------------------------------------------------------------------------------------------------------------------------------------------
# SVP only - Disease                          0.7000                0.7051                0.7735                0.7735                0.6691
# SVP only - Dataset                          0.8793                0.9010                0.8588                0.8588                0.8786
# DCP only - Disease                          0.5714                0.5974                0.5995                0.5995                0.5609
# DCP only - Dataset                          0.9511                0.9435                0.9682                0.9682                0.9264
# Concat - Disease                            0.6992                0.7632                0.7282                0.7282                0.8376
# Concat - Dataset                            0.9196                0.9434                0.9006                0.9006                0.9300
# Single - SVP vs DCP                         1.0000                1.0000                1.0000                1.0000                1.0000
